# %%
import pandas as pd
import numpy as np
import matplotlib as plt


#Load Caseload data
data = pd.read_csv("/home/yussuf/Desktop/Moringa/Introduction/Dummy_Data.csv")
#aggregating = data.groupby(["County","court_name"]).sum()
#court_level = data["court_level"]

data["court_name"] = [x.lower() for x in data["court_name"]]   # changing the All Courts in lower case
data.columns = [x.lower() for x in data.columns]    # changing all the headers in lower case



print(data.column)

'''
#print(data.head())

#Use County collumn as index collumn
#data.set_index("County",inplace=True)

# Generate the total filings by Courty
county_filings = data.groupby("County")[['Supreme - Filed', 'COA - CR filed', 
                                            'COA - CV filed', 'HC - CR filed', 'HC - CV filed',
                                            'ELRC - Filed cases','ELC - Filed cases',
                                            'MC - CR filed cases','MC - CV filed cases',
                                            'SCC - CR filed cases', 'SCC - CV filed cases', 
                                            'Kadhi Court - Filed cases']].sum()

#Generate Total resolved cases by County
county_resolution = data.groupby("County")[['Supreme - Resolved', 'COA - CR Resolved', 'COA - CV Resolved', 
                                            'HC - CR Resolved', 'HC - CV Resolved', 'ELRC - Resolved cases',
                                            'ELC - Resolved cases', 'MC - CR Resolved cases', 
                                            'MC - CV Resolved cases', 'SCC - CR Resolved cases',
                                            'SCC - CV Resolved cases', 'Kadhi Court - Resolved cases']].sum()

#Generate pending by County
county_pending = data.groupby("County")[['Supreme - Pending', 'COA - CR Pending', 
                                           'COA - CV Pending', 'HC - CR Pending', 'HC - CV Pending', 
                                           'ELRC - Pending cases', 
                                           'ELC - Pending cases', 'MC - CR Pending cases', 
                                           'MC - CV Pending cases', 
                                           'SCC - CR Pending cases', 'SCC - CV Pending cases', 
                                           'Kadhi Court - pending cases']].sum()
COA_filing = data.groupby(['County']) [['COA - CR filed', 'COA - CV filed']].sum()
HC_filing = data.groupby(['court_name'])[['HC - CR filed', 'HC - CV filed']].sum()

#Total Judiciary caseload filing by county
def filing_county():
    total_County_filing= county_filings.sum(axis=1)
    return total_County_filing
  
filing_county()




  
  #  conf_ts = data
   # conf_ts_cntry = conf_ts[conf_ts['Country/Region']==cntry]
    #final_dataset = conf_ts_cntry.T[4:].sum(axis='columns').diff().rolling(window=window).mean()[40:]
    #df = pd.DataFrame(final_dataset,columns=['Total'])
    #return df


#### Filed cases - by broad case type**********
def total_filings_hc():
  hc_criminal = data.loc[data['court_level']==3, ['HC - CR filed']].sum()
  hc_civil = data.loc[data['court_level']==3, ['HC - CV filed']].sum()
  total_hc = sum(hc_criminal, hc_civil)
  #print(hc_criminal, hc_civil, total_hc)
  return total_hc

total_filings_hc()




"""3. High Court Caseload Information"""
court_level = data['court_level']
def hc_ststions(data,court_level ='3'):
  hc_total = HC_filing.sum(axis=1)
  print(HC_filing)
  print(hc_total)
  return hc_total



#print(total)
#High Court filings
#def hc_cases():
 #   for i in data["court_level"]:
  #      if (i==3):
   #         HC_filings = data.query("court_level ==3")[HC_filings].sum()
    #    else:
     #       print()  
      #  return HC_filing


def high_court_filings():
    HC_total = HC_filing.sum(axis=1) 
    print(HC_total)
    return HC_total

#sc = data.query("court_level == 1")[HC_filing].sum()

#sc
#overall_judiciary_filings = aggregating.sum()
#print(f"Overall Judiciary filings: {total_filings}")
#overall_judiciary_filings
#total_filing

#def over_all_judiciary():
 #   total_judiciary = total_filing.sum()
  #  return total_judiciary
#over_all_judiciary()

#high_court_filings()
#total_judiciary
#court_pending
#aggregating
#county_filings
#HC_total
#df = df.astype('int64')

'''
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_6339/1014056096.py in ?()
#      12 data.columns = [x.lower() for x in data.columns]    # changing all the headers in lower case
#      13
#      14
#      15
# ---> 16 print(data.column)
#      17
#      18 '''
#      19 #print(data.head())
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'column'
